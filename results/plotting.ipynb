# %% [markdown]
# # Plotting for Sleep-consolidated Learning

# %% [markdown]
# ## Setup

# %%
# !pip install seaborn matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import wandb
import pandas as pd
import scipy
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from scipy.stats import pearsonr

# %% [markdown]
# ### Plotting setup

# %%
config_params = ['config/n_phases',
 'config/replay_ratio',
 'config/max_seq_length',
 'config/n_augmentations',
 'config/sleep_max_steps',
 'config/wake_block_steps',
 'config/contextualize_sleep',
 'config/sleep_loss_threshold']

config_params_formatted = ['N Phases',
 'Replay Ratio',
 'Max Sequence Length',
 'N Augs',
 'Sleep Steps',
 'Wake Steps',
 'Contextualize Sleep',
 'Sleep Loss Threshold']

config_format_map = dict(zip(config_params, config_params_formatted))
config_format_map.update(dict(zip(config_params_formatted, config_params)))

correlation_cmap = {
    "Pos": "#EC7272",
    "Neg": "#BCD9A2"
}

model_cmap = {
    "Baseline": "#98a0a2",
    "Baseline-like": "#BFC9CC",
    "Sleep": "#FFA95A"
}

# BabyLM Eval

babylm_tasks = [
    'blimp',
    'wug_adj',
    'wug_past',
    'entity_tracking',
    'overall'
]

babylm_tasks_formatted = [
    'BLiMP',
    'Wugs: Adj.',
    'Wugs: Past',
    'Entity Tracking',
    'Overall'
]

savefig_kwargs = {
    'dpi': 300,
    'bbox_inches': 'tight',
    'transparent': True
}

# %% [markdown]
# ## Sweeps

# %% [markdown]
# ### Read Wandb sweep data

# %%
api = wandb.Api()
wandb_entity = "lemn-lab"
wandb_project = "sleep-consolidated-learning"
wandb_sweep_ids = ["1eq32rsz", "360fgz0o"]
sweep_paths=[f"{wandb_entity}/{wandb_project}/{sweep_id}" for sweep_id in wandb_sweep_ids]
# Out:
# wandb: [wandb.Api()] Loaded credentials for https://api.wandb.ai from /Users/tzhang04/.netrc.

# %%
results = []
for sweep_id in wandb_sweep_ids:
    runs = api.runs(f"{wandb_entity}/{wandb_project}", filters={"sweep": sweep_id})
    for run in runs:
        result = dict(run.summary)
        sleep_configs = {f"config/{key}":value for key, value in run.config['sleep_mechanism'].items()}
        result.update(sleep_configs)
        result.update({
            'id': run.id
        })
        results.append(result)
results = pd.DataFrame(results)
results = results.set_index('id')
results.shape
# Out:
# (53, 43)

# %%
eval_metrics = [col for col in results.columns if "eval" in col]
train_metrics = [col for col in results.columns if "train" in col]
# config_params = [col for col in results.columns if "config" in col]
config_params = [
    "config/replay_ratio",
    "config/sleep_max_steps",
    "config/n_phases",
    "config/contextualize_sleep"
]
eval_metric = 'eval/best_perplexity_mean'

# %%
config_params
# Out:
# ['config/replay_ratio',
#  'config/sleep_max_steps',
#  'config/n_phases',
#  'config/contextualize_sleep']

# %% [markdown]
# ### Check importance and correlation of parameters

# %%
data = results[config_params + [eval_metric]]
filter_unchanged_params = lambda col: data[col].value_counts().shape[0] > 1
data[config_params] = StandardScaler().fit_transform(data[config_params])
# Filter out unchanged parameters and NaNs
params_of_interest = list(filter(filter_unchanged_params, config_params))
data = data.loc[:, params_of_interest + [eval_metric]]
data = data[data.isna().sum(axis=1) == 0]
X = data[params_of_interest]
y = data[[eval_metric]]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
y_hat = linear_model.predict(X_test)
mse(y_test, y_hat)
# Out:
# 501247.66265310446

# %%
rf_model = RandomForestRegressor(n_estimators=1000)
rf_model.fit(X_train, y_train)
y_hat = rf_model.predict(X_test)
mse(y_test, y_hat)
# Out:
# /Users/tzhang04/Desktop/BabyLM/sleep/sleep-plotting/lib/python3.11/site-packages/sklearn/base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 629644.1662996705

# %%
correlations = []
for param in params_of_interest:
    corr = pearsonr(data[param], data[eval_metric])
    correlations.append(corr.statistic)

# %%
bootstrap_results = []
n_bootstraps = 100
for _ in range(n_bootstraps):
    bootstrapped_data = data.sample(data.shape[0], replace=True)
    
    # rf feature importances
    X = bootstrapped_data[params_of_interest]
    y = bootstrapped_data[[eval_metric]].to_numpy().ravel()
    rf_model = RandomForestRegressor(n_estimators=1000)
    rf_model.fit(X, y)
    feature_importances = dict(zip(params_of_interest, rf_model.feature_importances_))
    for param in params_of_interest:
        # correlation
        corr = pearsonr(bootstrapped_data[param], bootstrapped_data[eval_metric])
        result = {
            "Parameter": config_format_map[param],
            "Parameter Importance": feature_importances[param],
            "Correlation": corr[0]
        }
        bootstrap_results.append(result)
bootstrap_results = pd.DataFrame(bootstrap_results)
bootstrap_results
# Out:
#                Parameter  Parameter Importance  Correlation
# 0           Replay Ratio              0.325150     0.142791
# 1            Sleep Steps              0.253138     0.026610
# 2               N Phases              0.384665     0.352381
# 3    Contextualize Sleep              0.037048     0.302829
# 4           Replay Ratio              0.182052    -0.034267
# ..                   ...                   ...          ...
# 395  Contextualize Sleep              0.013748     0.030868
# 396         Replay Ratio              0.295397    -0.031420
# 397          Sleep Steps              0.322446     0.077825
# 398             N Phases              0.316399     0.381998
# 399  Contextualize Sleep              0.065759     0.010087
#
# [400 rows x 3 columns]

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharey=True)
formatted_params = [config_format_map[param] for param in params_of_interest]
bootstrap_results = bootstrap_results.sort_values("Parameter")
# importance
axs[0].grid(axis='x', zorder=0)
sns.barplot(bootstrap_results.sort_values("Parameter Importance", ascending=False), y='Parameter', x='Parameter Importance', ax=axs[0],
            color="#9CD5FF", zorder=2)
axs[0].set_title("Parameter Importance")
axs[0].set_xlabel("")
axs[0].set_ylabel("")
# axs[0].set_xlim(0, 1)

# correlation
corr_colors = [correlation_cmap['Pos'] if corr > 0 else correlation_cmap['Neg']
               for corr in bootstrap_results.groupby('Parameter')['Correlation'].mean()]
sns.barplot(bootstrap_results, y='Parameter', x='Correlation', hue='Parameter', ax=axs[1],
            palette=corr_colors, legend=False, zorder=2)
axs[1].set_title("Feature Correlation w. Perplexity",
                #  fontsize=16, fontweight="bold"
                 )
# axs[1].set_xlabel("Correlation with Perplexity")
axs[1].set_xlabel("")
axs[1].set_ylabel("")
axs[1].grid(axis='x')
# axs[1].set_xlim(-0.25, 0.25)

plt.tight_layout()
plt.savefig("plots/sweep_para_results.png",
            **savefig_kwargs)
;
# Out:
# ''

# %% [markdown]
# ### Perplexity Heatmap

# %%
results.groupby(["config/n_phases", "config/replay_ratio"])["eval/best_perplexity_mean"].mean().reset_index()
# Out:
#    config/n_phases  config/replay_ratio  eval/best_perplexity_mean
# 0                1                  0.2                 897.855489
# 1                1                  0.6                 897.986938
# 2                1                  1.0                 897.986938
# 3               50                  0.2                 330.379410
# 4               50                  0.6                 163.801760
# 5               50                  1.0                 412.153776
# 6              100                  0.2                2247.546468
# 7              100                  0.6                 974.046178
# 8              100                  1.0                1813.423126

# %%
pivot=results.pivot_table(values="eval/best_perplexity_mean",
                index="config/n_phases",
                columns="config/replay_ratio",
                aggfunc=np.mean)
sns.heatmap(pivot, cmap='flare',
            cbar_kws={'label': 'Perplexity'})
plt.title("Test perplexity by hyperparameter")
plt.ylabel("N Phases")
plt.xlabel("Replay Ratio")
plt.savefig("plots/ppl_heatmap.png",
            **savefig_kwargs)

# %%
fig, axs = plt.subplots(2, 4, figsize=(17, 10),
                        width_ratios=[12, 12, 12, 1],)
max_ppl = results['eval/best_perplexity_mean'].max()
min_ppl = results['eval/best_perplexity_mean'].min()
for row, context in zip(axs, [False, True]):
    for ax, steps in zip(row[:-1], results['config/sleep_max_steps'].unique()):
        pivot = (results[(results['config/sleep_max_steps'] == steps)
                         & (results['config/contextualize_sleep']==context)]
                .pivot_table(values="eval/best_perplexity_mean",
                    index="config/n_phases",
                    columns="config/replay_ratio",
                    aggfunc=np.mean))
        sns.heatmap(pivot, ax=ax, vmin=min_ppl, vmax=max_ppl, cmap='flare',
                    cbar=(ax==row[-2]), cbar_ax=row[-1],
                    cbar_kws={'label': 'Eval Perplexity (lower is better)'}, annot=True)
        ax.set_title(f"Sleep steps = {steps}, Contextualize = {context}")
        ax.set_ylabel("Num. Phases" if ax in axs[:, 0] else "")
        ax.set_xlabel("Replay Ratio" if ax in axs[-1, :] else "")
fig.suptitle("Sleep Mechanism: Grid Search Results", fontsize=24, fontweight="bold")
plt.tight_layout()
plt.savefig("plots/gridsearch_heatmap.png", 
            **savefig_kwargs)

# %% [markdown]
# ### BabyLM Evals

# %%
eval_metrics
# Out:
# ['eval/before_SLEEP_perplexity_max',
#  'eval/before_SLEEP_perplexity_mean',
#  'eval/before_SLEEP_perplexity_std',
#  'eval/before_SLEEP_runtime',
#  'eval/best_model_step',
#  'eval/best_perplexity_max',
#  'eval/best_perplexity_mean',
#  'eval/best_perplexity_std',
#  'eval/best_runtime',
#  'eval/perplexity_max',
#  'eval/perplexity_mean',
#  'eval/perplexity_std',
#  'eval/runtime',
#  'eval/before_WAKE_perplexity_max',
#  'eval/before_WAKE_perplexity_mean',
#  'eval/before_WAKE_perplexity_std',
#  'eval/before_WAKE_runtime']

# %% [markdown]
# ## Replay Experiment

# %%
random_run = api.run(f"{wandb_entity}/{wandb_project}/z61n2zkz")
weighted_run = api.run(f"{wandb_entity}/{wandb_project}/vj4c9fev")
strict_run = api.run(f"{wandb_entity}/{wandb_project}/hxuu5fxg")

# %%
random_run.summary
# Out:
# {'_runtime': 30808, '_step': 2126, '_timestamp': 1771861048.2346275, '_wandb': {'runtime': 30808}, 'eval/babylm_TEMPERATURE': 1, 'eval/babylm_adjunct_island': 45, 'eval/babylm_anaphor_agreement': 58.5, 'eval/babylm_anaphor_gender_agreement': 57, 'eval/babylm_anaphor_number_agreement': 60, 'eval/babylm_animate_subject_passive': 54, 'eval/babylm_animate_subject_trans': 72.5, 'eval/babylm_argument_structure': 52.14, 'eval/babylm_avg': 51.97030303030302, 'eval/babylm_binding': 57.86, 'eval/babylm_causative': 45, 'eval/babylm_complex_NP_island': 54.5, 'eval/babylm_control_raising': 53.9, 'eval/babylm_coordinate_structure_constraint_complex_left_branch': 31.5, 'eval/babylm_coordinate_structure_constraint_object_extraction': 62, 'eval/babylm_determiner_noun_agreement': 65.69, 'eval/babylm_determiner_noun_agreement_1': 60, 'eval/babylm_determiner_noun_agreement_2': 67.5, 'eval/babylm_determiner_noun_agreement_irregular_1': 64.5, 'eval/babylm_determiner_noun_agreement_irregular_2': 83, 'eval/babylm_determiner_noun_agreement_with_adj_2': 61.5, 'eval/babylm_determiner_noun_agreement_with_adj_irregular_1': 61, 'eval/babylm_determiner_noun_agreement_with_adj_irregular_2': 71.5, 'eval/babylm_determiner_noun_agreement_with_adjective_1': 56.5, 'eval/babylm_distractor_agreement_relational_noun': 38.5, 'eval/babylm_distractor_agreement_relative_clause': 37.5, 'eval/babylm_drop_argument': 55, 'eval/babylm_ellipsis': 47.25, 'eval/babylm_ellipsis_n_bar_1': 58.5, 'eval/babylm_ellipsis_n_bar_2': 36, 'eval/babylm_existential_there_object_raising': 60.5, 'eval/babylm_existential_there_quantifiers_1': 75.5, 'eval/babylm_existential_there_quantifiers_2': 42.5, 'eval/babylm_existential_there_subject_raising': 47, 'eval/babylm_expletive_it_object_raising': 67.5, 'eval/babylm_filler_gap_dependency': 60.43, 'eval/babylm_hypernym': 52, 'eval/babylm_inchoative': 39.5, 'eval/babylm_intransitive': 45.5, 'eval/babylm_irregular_forms': 48.25, 'eval/babylm_irregular_past_participle_adjectives': 34.5, 'eval/babylm_irregular_past_participle_verbs': 62, 'eval/babylm_irregular_plural_subject_verb_agreement_1': 56, 'eval/babylm_irregular_plural_subject_verb_agreement_2': 63.5, 'eval/babylm_island_effects': 56.19, 'eval/babylm_left_branch_island_echo_question': 91.5, 'eval/babylm_left_branch_island_simple_question': 47, 'eval/babylm_matrix_question_npi_licensor_present': 17.5, 'eval/babylm_morphology': 58.19, 'eval/babylm_npi_licensing': 45.14, 'eval/babylm_npi_present_1': 41.5, 'eval/babylm_npi_present_2': 40, 'eval/babylm_only_npi_licensor_present': 30.5, 'eval/babylm_only_npi_scope': 39.5, 'eval/babylm_passive_1': 60.5, 'eval/babylm_passive_2': 60, 'eval/babylm_principle_A_c_command': 48, 'eval/babylm_principle_A_case_1': 97, 'eval/babylm_principle_A_case_2': 60, 'eval/babylm_principle_A_domain_1': 84, 'eval/babylm_principle_A_domain_2': 52, 'eval/babylm_principle_A_domain_3': 47, 'eval/babylm_principle_A_reconstruction': 17, 'eval/babylm_qa_congruence_easy': 36, 'eval/babylm_qa_congruence_tricky': 22, 'eval/babylm_quantifiers': 46.88, 'eval/babylm_regular': 36.4, 'eval/babylm_regular_0_ops': 23.27, 'eval/babylm_regular_1_ops': 36.74, 'eval/babylm_regular_2_ops': 42.41, 'eval/babylm_regular_3_ops': 35.15, 'eval/babylm_regular_4_ops': 36.8, 'eval/babylm_regular_5_ops': 44.03, 'eval/babylm_regular_plural_subject_verb_agreement_1': 55, 'eval/babylm_regular_plural_subject_verb_agreement_2': 58, 'eval/babylm_s-selection': 63.25, 'eval/babylm_semantics': 45.33, 'eval/babylm_sentential_negation_npi_licensor_present': 91, 'eval/babylm_sentential_negation_npi_scope': 56, 'eval/babylm_sentential_subject_island': 61, 'eval/babylm_subject_aux_inversion': 72, 'eval/babylm_subject_verb_agreement': 51.42, 'eval/babylm_superlative_quantifiers_1': 33, 'eval/babylm_superlative_quantifiers_2': 36.5, 'eval/babylm_supplement': 47.2, 'eval/babylm_syntax': 56.1, 'eval/babylm_syntax/semantics': 55, 'eval/babylm_tough_vs_raising_1': 55.5, 'eval/babylm_tough_vs_raising_2': 39, 'eval/babylm_tr ...

# %%
runs = [random_run, weighted_run, strict_run]
run_data=pd.DataFrame({
    "Run": ["Random", "Weighted", "Strict"],
    "Mean PPL": [run.summary['eval/best_perplexity_mean'] for run in runs],
    "Max PPL": [run.summary['eval/best_perplexity_max'] for run in runs],
    "STD PPL": [run.summary['eval/best_perplexity_std'] for run in runs],
    "BabyLM": [run.summary['eval/best_babylm_avg'] for run in runs],
})

# %%
fig, axs = plt.subplots(1, 3, figsize=(6, 3), sharex=True)
# Mean PPL
axs[0].grid(axis='y', zorder=0)
sns.barplot(run_data, y='Mean PPL', x='Run', ax=axs[0],
            color="#9CD5FF", zorder=2)
axs[0].set_title("Mean Test PPL")
axs[0].set_xlabel("")
axs[0].set_ylabel("")

# STD of PPL
axs[1].grid(axis='y', zorder=0)
sns.barplot(run_data, y='STD PPL', x='Run', ax=axs[1],
            color="#9CD5FF", zorder=2)
axs[1].set_title("STD of Test PPL")
axs[1].set_xlabel("")
axs[1].set_ylabel("")

# correlation
sns.barplot(run_data, y='BabyLM', x='Run', ax=axs[2],
            color="#9CD5FF", zorder=2)
axs[2].set_title("Linguistic Acc.")
axs[2].set_xlabel("")
axs[2].set_ylabel("")
axs[2].grid(axis='y')
axs[2].set_ylim(0, 100)
axs[2].axhline(y=50, color=correlation_cmap['Pos'], linestyle="--")

for ax in axs:
    ax.set_xticks(ticks=run_data['Run'], labels=run_data['Run'], rotation=45)

plt.tight_layout()
plt.savefig("plots/replay_strat_results.png",
            dpi=300, bbox_inches='tight',
            transparent=True)
;
# Out:
# ''

# %% [markdown]
# ## Graphing Training Loss

# %%
eval_metrics
# Out:
# ['eval/before_SLEEP_perplexity_max',
#  'eval/before_SLEEP_perplexity_mean',
#  'eval/before_SLEEP_perplexity_std',
#  'eval/before_SLEEP_runtime',
#  'eval/best_model_step',
#  'eval/best_perplexity_max',
#  'eval/best_perplexity_mean',
#  'eval/best_perplexity_std',
#  'eval/best_runtime',
#  'eval/perplexity_max',
#  'eval/perplexity_mean',
#  'eval/perplexity_std',
#  'eval/runtime',
#  'eval/before_WAKE_perplexity_max',
#  'eval/before_WAKE_perplexity_mean',
#  'eval/before_WAKE_perplexity_std',
#  'eval/before_WAKE_runtime']

# %%
best_run_id = results.sort_values('eval/best_perplexity_mean', ascending=True).index[0]
best_run_id
# Out:
# 'ivws1mnn'

# %%
runs = api.runs(f"{wandb_entity}/{wandb_project}", filters={"sweep": wandb_sweep_id})
best_run = [run for run in runs if run.id == best_run_id][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 runs = api.runs(f"{wandb_entity}/{wandb_project}", filters={"sweep": wandb_sweep_id})
#       2 best_run = [run for run in runs if run.id == best_run_id][0]
#
# NameError: name 'wandb_sweep_id' is not defined

# %%
results.loc[[best_run_id]]
# Out:
#              _runtime  _step    _timestamp             _wandb  \
# id
# egsiqgxx  4386.475343   2167  1.771677e+09  {'runtime': 4387}
#
#           eval/before_SLEEP_perplexity_max  eval/before_SLEEP_perplexity_mean  \
# id
# egsiqgxx                       6578.293457                         667.283386
#
#           eval/before_SLEEP_perplexity_std  eval/before_SLEEP_runtime  \
# id
# egsiqgxx                        899.225586                     7.9966
#
#           eval/before_WAKE_perplexity_max  eval/before_WAKE_perplexity_mean  \
# id
# egsiqgxx                      5378.240234                        738.875916
#
#           ...  train_samples_per_second  train_steps_per_second  \
# id        ...
# egsiqgxx  ...                   391.767                   6.121
#
#           config/n_phases  config/replay_ratio  config/max_seq_length  \
# id
# egsiqgxx               50              0.56139                    128
#
#           config/n_augmentations  config/sleep_max_steps  \
# id
# egsiqgxx                      40                     500
#
#           config/wake_block_steps  config/contextualize_sleep  \
# id
# egsiqgxx                  9999999                        True
#
#           config/sleep_loss_threshold
# id
# egsiqgxx                          0.5
#
# [1 rows x 42 columns]

# %%
keys = [
    'train/loss_mlm',
    'train/loss_mlm_SLEEP',
    'train/loss_mlm_WAKE',
    'eval/before_SLEEP_perplexity_mean',
    'eval/before_WAKE_perplexity_mean'
]
histories = []
for key in keys:
    hist = best_run.history(keys=[key])
    histories.append(hist)
best_run_history = histories[0]
for hist in histories[1:]:
    best_run_history = best_run_history.merge(hist, on='_step', how='outer')
best_run_history['train_PPL'] = (best_run_history['eval/before_SLEEP_perplexity_mean'].fillna(0) 
                                 + best_run_history['eval/before_WAKE_perplexity_mean'].fillna(0))

# %%
phase = []
curr_phase = "WAKE"
for ppl in best_run_history['train_PPL']:
    phase.append(curr_phase)
    if ppl != 0:
        curr_phase = "SLEEP" if curr_phase == "WAKE" else "WAKE"
best_run_history['phase'] = phase
# best_run_history['train/loss_mlm_SLEEP'] = best_run_history['train/loss_mlm_SLEEP'].fillna(np.inf)
# best_run_history['train/loss_mlm_WAKE'] = best_run_history['train/loss_mlm_WAKE'].fillna(np.inf)

# %%
best_run_history.head()
# Out:
#    _step  train/loss_mlm  train/loss_mlm_SLEEP  train/loss_mlm_WAKE  \
# 0      2        1.301908                   NaN             1.301908
# 1      4        1.284770                   NaN             1.284770
# 2      5             NaN                   NaN                  NaN
# 3      7             NaN              8.863770                  NaN
# 4      9             NaN              8.518527                  NaN
#
#    eval/before_SLEEP_perplexity_mean  eval/before_WAKE_perplexity_mean  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                        8427.470703                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
#
#      train_PPL  phase
# 0     0.000000   WAKE
# 1     0.000000   WAKE
# 2  8427.470703   WAKE
# 3     0.000000  SLEEP
# 4     0.000000  SLEEP

# %%
ppl_changes_after_sleep = (
    best_run_history.loc[~best_run_history['eval/before_WAKE_perplexity_mean'].isna(),
                      'eval/before_WAKE_perplexity_mean'].reset_index(drop=True)
    - best_run_history.loc[~best_run_history['eval/before_SLEEP_perplexity_mean'].isna(),
                      'eval/before_SLEEP_perplexity_mean'].reset_index(drop=True)
 )

# %%
sns.lineplot(ppl_changes_after_sleep)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.4)
plt.title('PPL Changes after sleep phases')
plt.xlabel('Sleep Phase no.')
plt.ylabel('Eval Perplexity')
# Out:
# Text(0, 0.5, 'Eval Perplexity')

# %%
ppl_changes_after_wake = (
    best_run_history.loc[~best_run_history['eval/before_SLEEP_perplexity_mean'].isna(),
                      'eval/before_SLEEP_perplexity_mean'].reset_index(drop=True).iloc[1:]
    - best_run_history.loc[~best_run_history['eval/before_WAKE_perplexity_mean'].isna(),
                      'eval/before_WAKE_perplexity_mean'].reset_index(drop=True)
 )

# %%
sns.scatterplot(ppl_changes_after_wake)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.4)
plt.title('PPL Changes after wake phases')
plt.xlabel('Sleep Phase no.')
plt.ylabel('Eval Perplexity')
# Out:
# Text(0, 0.5, 'Eval Perplexity')

# %%
best_run_history.loc[best_run_history['train_PPL'] > 0]
# Out:
#      _step  train/loss_mlm  train/loss_mlm_SLEEP  train/loss_mlm_WAKE  \
# 2        5             NaN                   NaN                  NaN
# 16      44             NaN                   NaN                  NaN
# 18      47             NaN                   NaN                  NaN
# 28      88             NaN                   NaN                  NaN
# 30      91             NaN                   NaN                  NaN
# ..     ...             ...                   ...                  ...
# 852   2040             NaN                   NaN                  NaN
# 868   2079             NaN                   NaN                  NaN
# 871   2084             NaN                   NaN                  NaN
# 888   2123             NaN                   NaN                  NaN
# 890   2126             NaN                   NaN                  NaN
#
#      eval/before_SLEEP_perplexity_mean  eval/before_WAKE_perplexity_mean  \
# 2                          8427.470703                               NaN
# 16                                 NaN                       1182.765503
# 18                         1188.276978                               NaN
# 28                                 NaN                       1127.874634
# 30                         1121.202881                               NaN
# ..                                 ...                               ...
# 852                         150.265808                               NaN
# 868                                NaN                        380.601654
# 871                         391.293213                               NaN
# 888                                NaN                        738.875916
# 890                         667.283386                               NaN
#
#        train_PPL  phase
# 2    8427.470703   WAKE
# 16   1182.765503  SLEEP
# 18   1188.276978   WAKE
# 28   1127.874634  SLEEP
# 30   1121.202881   WAKE
# ..           ...    ...
# 852   150.265808   WAKE
# 868   380.601654  SLEEP
# 871   391.293213   WAKE
# 888   738.875916  SLEEP
# 890   667.283386   WAKE
#
# [99 rows x 8 columns]

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 3))
data=best_run_history.loc[best_run_history['train_PPL'] > 0]
x=data['_step']
y=data['train_PPL']

# Define alternating colors
colors = ['steelblue', 'tomato']

# Plot each segment between consecutive points with alternating colors
for i in range(len(x) - 1):
    color = colors[i % len(colors)]
    ax.plot(x[i:i+2], y[i:i+2], color=color, linewidth=2, marker='.')
    
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=colors[0], label='Sleep PPL'),
                   Patch(facecolor=colors[1], label='Wake PPL'),
                   Patch(facecolor='cyan', label='Train BCE Loss')
                ]

ax2 = ax.twinx()
sns.lineplot(best_run_history, x='_step', y='train/loss_mlm', ax=ax2, color='cyan', alpha=0.5, linestyle='--')
ax.legend(handles=legend_elements)
plt.title('Eval perplexity between phases')
plt.xlabel('Step #')
# plt.xlim(0, 300)
ax.set_ylabel('Eval Perplexity')
ax2.set_ylabel('BCE Loss')
fig.savefig("plots/ppl_phases", dpi=300, bbox_inches='tight')

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 3))
data=best_run_history
x=data['_step']
y=data['train/loss_mlm']
phases = data['phase']

# Define alternating colors
colors = {'SLEEP': 'steelblue', 
          'WAKE': 'tomato'}

# Plot each segment between consecutive points with alternating colors
for i in range(len(x) - 1):
    color = colors[phases[i]]
    ax.plot(x[i:i+2], y[i:i+2], color=color, linewidth=2, marker='.')
    
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=colors['SLEEP'], label='Sleep phase'),
                   Patch(facecolor=colors['WAKE'], label='Wake phase'),
                #    Patch(facecolor='cyan', label='Train Loss')
                   ]

# ax2 = ax.twinx()
# sns.lineplot(best_run_history, x='_step', y='train/loss_mlm', ax=ax2, color='cyan', alpha=0.5, linestyle='--')
ax.legend(handles=legend_elements)
plt.title('BCE loss between phases')
plt.xlabel('Step #')
ax.set_ylabel('MLM BCE Loss')
# ax2.set_ylabel('BCE Loss')
# fig.savefig("plots/ppl_phases", dpi=200, bbox_inches='tight')
# Out:
# Text(0, 0.5, 'MLM BCE Loss')

# %%
# # !pip install plotly
# # import plotly
# # import plotly.graph_objects as go

# # Filter data
# data = best_run_history.loc[best_run_history['train_PPL'] > 0]
# x = data['_step'].values
# y = data['train_PPL'].values
# y2 = data['train/loss_mlm'].values

# colors = ['steelblue', 'tomato']

# fig = go.Figure()

# # Alternating segments for PPL
# for i in range(len(x) - 1):
#     color = colors[i % len(colors)]
#     name = 'Sleep PPL' if i % 2 == 0 else 'Wake PPL'
    
#     fig.add_trace(
#         go.Scatter(
#             x=x[i:i+2],
#             y=y[i:i+2],
#             mode='lines+markers',
#             line=dict(color=color, width=2),
#             marker=dict(size=6),
#             name=name,
#             legendgroup=name,
#             showlegend=(i < 2)  # show each legend entry only once
#         )
#     )

# # Secondary y-axis for BCE loss
# fig.add_trace(
#     go.Scatter(
#         x=x,
#         y=y2,
#         mode='lines',
#         line=dict(color='cyan', dash='dash'),
#         name='Train BCE Loss',
#         yaxis='y2',
#         opacity=0.6
#     )
# )

# # Layout with secondary axis
# fig.update_layout(
#     title='Eval perplexity between phases',
#     xaxis=dict(title='Step #'),
#     yaxis=dict(title='Eval Perplexity'),
#     yaxis2=dict(
#         title='BCE Loss',
#         overlaying='y',
#         side='right'
#     ),
#     legend=dict(title='Metrics'),
#     template='plotly_white',
#     hovermode='x unified'
# )

# fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       1 # !pip install plotly
#       2 # import plotly
#       3 # import plotly.graph_objects as go
#       4
#       5 # Filter data
# ----> 6 data = best_run_history.loc[best_run_history['train_PPL'] > 0]
#       7 x = data['_step'].values
#       8 y = data['train_PPL'].values
#
# NameError: name 'best_run_history' is not defined

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- -------------
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# applaunchservices                 0.3.0
# appnope                           0.1.2
# appscript                         1.1.2
# archspec                          0.2.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             23.1.0
# autograd                          1.8.0
# autograd-gamma                    0.5.0
# Automat                           20.2.0
# autopep8                          1.6.0
# Babel                             2.11.0
# backports.functools-lru-cache     1.6.4
# backports.tarfile                 1.2.0
# backports.tempfile                1.0
# backports.weakref                 1.0.post1
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.2
# binaryornot                       0.4.4
# black                             23.11.0
# bleach                            4.1.0
# blinker                           1.6.2
# blis                              1.0.1
# bokeh                             3.3.4
# boltons                           23.0.0
# botocore                          1.31.64
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# build                             1.2.2.post1
# CacheControl                      0.14.1
# cachetools                        4.2.2
# catalogue                         2.0.10
# certifi                           2024.2.2
# cffi                              1.16.0
# chardet                           4.0.0
# charset-normalizer                2.0.4
# cleo                              2.1.0
# click                             8.1.7
# cloudpathlib                      0.20.0
# cloudpickle                       2.2.1
# clyent                            1.2.2
# colorama                          0.4.6
# colorcet                          3.0.1
# comm                              0.1.2
# conda                             24.1.2
# conda-build                       24.1.2
# conda-content-trust               0.2.0
# conda_index                       0.4.0
# conda-libmamba-solver             24.1.0
# conda-pack                        0.6.0
# conda-package-handling            2.2.0
# conda_package_streaming           0.9.0
# conda-repo-cli                    1.0.75
# conda-token                       0.4.0
# conda-verify                      3.4.2
# confection                        0.1.5
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.5.0
# crashtest                         0.4.1
# cryptography                      42.0.2
# cssselect                         1.2.0
# cycler                            0.11.0
# cymem                             2.0.8
# cytoolz                           0.12.2
# dask                              2023.11.0
# datashader                        0.16.0
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.7
# distlib                           0.3.9
# distributed                       2023.11.0
# distro                            1.8.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# dulwich                           0.22.7
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# executing                         0.8.3
# fastjsonschema                    2.20.0
# filelock                          3.13.1
# flake8                            6.0.0
# Flask                             2.2.5
# fonttools                         4.25.0
# formulaic                         1.2.1
# fqdn                              1.5.1
# frozenlist                        1.4.0
# fsspec                            2023.10.0
# future                            0.18.3
# gensim                            4.3.0
# gitdb                             4.0.7
# GitPython                         3.1.37
# gmpy2                             2.1.2
# greenlet                          3.0.1
# h5py                              3.9.0
# HeapDict                          1.0.1
# hf-xet                            1.1.10
# holoviews                         1.18.3
# huggingface-hub                   0.35.3
# hvplot                            0.9.2
# hyperlink                         21.0.0
# idna                              3.4
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.11.0
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# inquirerpy                        0.3.4
# installer                         0.7.0
# intake                            0.6.8
# interface-meta                    1.3.0
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.20.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.5
# ISLP                              0.4.0
# isoduration                       20.11.0
# isort                             5.9.3
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.0.1
# jaraco.classes                    3.2.1
# jaraco.context                    6.0.1
# jaraco.functools                  4.1.0
# jedi                              0.18.1
# jellyfish                         1.0.1
# Jinja2                            3.1.3
# jmespath                          1.0.1
# joblib                            1.2.0
# json5                             0.9.6
# jsonpatch                         1.32
# jsonpointer                       2.1
# jsonschema                        4.19.2
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.5.0
# jupyter-events                    0.8.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.10.0
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.0.11
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.25.1
# jupyterlab-widgets                3.0.9
# keyring                           25.6.0
# kiwisolver                        1.4.4
# langcodes                         3.4.1
# language_data                     1.2.0
# lazy_loader                       0.3
# lazy-object-proxy                 1.6.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      2.9
# libmambapy                        1.5.6
# lifelines                         0.30.0
# lightning-utilities               0.15.2
# linkify-it-py                     2.0.0
# llvmlite                          0.42.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              4.9.3
# lz4                               4.3.2
# marisa-trie                       1.2.1
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.8.0
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.0.2
# miditok                           3.0.5.post1
# MIDIUtil                          1.2.1
# mistune                           2.0.4
# more-itertools                    10.1.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# munkres                           1.1.4
# murmurhash                        1.0.10
# mypy                              1.8.0
# mypy-extensions                   1.0.0
# narwhals                          2.10.0
# navigator-updater                 0.4.0
# nbclient                          0.8.0
# nbconvert                         7.10.0
# nbformat                          5.9.2
# nest-asyncio                      1.6.0
# networkx                          3.1
# nltk                              3.8.1
# notebook                          7.0.8
# notebook_shim                     0.2.3
# numba                             0.59.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.5.0
# openpyxl                          3.0.10
# overrides                         7.4.0
# packaging                         24.2
# pandas                            2.1.4
# pandoc                            2.3
# pandocfilters                     1.5.0
# panel                             1.3.8
# param                             2.0.2
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathlib                           1.0.1
# pathspec                          0.10.3
# patsy                             0.5.3
# pexpect                           4.8.0
# pfzy                              0.3.4
# pickleshare                       0.7.5
# pillow                            10.2.0
# pip                               26.0.1
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      3.10.0
# plotly                            6.5.2
# pluggy                            1.0.0
# plumbum                           1.8.2
# ply                               3.11
# poetry                            2.0.0
# poetry-core                       2.0.0
# poetry-plugin-export              1.8.0
# preshed                           3.0.9
# progressbar2                      4.5.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          3.20.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           14.0.2
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.10.0
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.2
# pydantic                          1.10.12
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.0
# pyflakes                          3.0.1
# pygam                             0.10.1
# Pygments                          2.15.1
# PyJWT                             2.4.0
# pylint                            2.16.2
# pylint-venv                       2.3.0
# pyls-spyder                       0.4.0
# pyobjc-core                       9.0
# pyobjc-framework-Cocoa            9.0
# pyobjc-framework-CoreServices     9.0
# pyobjc-framework-FSEvents         9.0
# pyodbc                            5.0.1
# pyOpenSSL                         24.0.0
# pyparsing                         3.0.9
# pyproject_hooks                   1.2.0
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# pySmartDL                         1.3.4
# PySocks                           1.7.1
# pytest                            7.4.0
# python-dateutil                   2.8.2
# python-dotenv                     0.21.0
# python-json-logger                2.0.7
# python-lsp-black                  1.2.1
# python-lsp-jsonrpc                1.0.0
# python-lsp-server                 1.7.2
# python-slugify                    5.0.2
# python-snappy                     0.6.1
# python-utils                      3.9.1
# pytoolconfig                      1.2.6
# pytorch-lightning                 2.5.5
# pytz                              2023.3.post1
# pyviz_comms                       3.0.0
# pywavelets                        1.5.0
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.0.2
# qstylizer                         0.2.2
# QtAwesome                         1.2.2
# qtconsole                         5.4.2
# QtPy                              2.4.1
# queuelib                          1.6.2
# RapidFuzz                         3.10.1
# referencing                       0.30.2
# regex                             2023.10.3
# requests                          2.31.0
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.3.5
# rope                              1.7.0
# rpds-py                           0.10.6
# Rtree                             1.0.1
# ruamel.yaml                       0.17.21
# ruamel-yaml-conda                 0.17.21
# s3fs                              2023.10.0
# scikit-image                      0.22.0
# scikit-learn                      1.2.2
# scipy                             1.11.4
# Scrapy                            2.8.0
# seaborn                           0.12.2
# semver                            2.13.0
# Send2Trash                        1.8.2
# service-identity                  18.1.0
# setuptools                        75.5.0
# shellingham                       1.5.4
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# spacy                             3.8.2
# spacy-legacy                      3.0.12
# spacy-loggers                     1.0.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.5
# spyder                            5.4.3
# spyder-kernels                    2.4.4
# SQLAlchemy                        2.0.25
# srsly                             2.4.8
# stack-data                        0.2.0
# statsmodels                       0.14.0
# streamlit                         1.30.0
# sympy                             1.14.0
# symusic                           0.5.8
# tables                            3.9.2
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.2
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# thinc                             8.3.2
# threadpoolctl                     2.2.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tinycss2                          1.2.1
# tldextract                        3.2.0
# tokenizers                        0.21.1
# toml                              0.10.2
# tomlkit                           0.13.2
# toolz                             0.12.0
# torch                             2.7.0
# torchmetrics                      1.8.2
# tornado                           6.3.3
# tqdm                              4.65.0
# traitlets                         5.7.1
# trove-classifiers                 2024.10.21.16
# truststore                        0.8.0
# Twisted                           23.10.0
# typer                             0.13.0
# typing_extensions                 4.14.0
# tzdata                            2023.3
# tzlocal                           2.1
# uc-micro-py                       1.0.1
# ujson                             5.4.0
# Unidecode                         1.2.0
# uri-template                      1.3.0
# urllib3                           2.0.7
# validators                        0.18.2
# vega-datasets                     0.9.0
# virtualenv                        20.27.1
# w3lib                             2.1.2
# wasabi                            1.1.3
# watchdog                          2.1.6
# wcwidth                           0.2.5
# weasel                            0.4.1
# webcolors                         25.10.0
# webencodings                      0.5.1
# websocket-client                  0.58.0
# Werkzeug                          2.2.3
# whatthepatch                      1.0.2
# wheel                             0.45.0
# widgetsnbextension                3.5.2
# wrapt                             1.14.1
# wurlitzer                         3.0.2
# xarray                            2023.6.0
# xattr                             1.1.0
# xlwings                           0.29.1
# xyzservices                       2022.9.0
# yapf                              0.31.0
# yarl                              1.9.3
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.19.0

# %% [markdown]
# ## BabyLM Evaluation

# %%
runs_to_test = {
    'Baseline-like': api.run(f"{wandb_entity}/{wandb_project}/f69xpsbc"),
    'Baseline': api.run(f"{wandb_entity}/{wandb_project}/jum8dpsr"),
    'Sleep': api.run(f"{wandb_entity}/{wandb_project}/hxuu5fxg")
}

# %%
results = []
for run_name, run in runs_to_test.items():
    result = {
        'run': run_name,
    }
    # result.update({f"config/{key}":value for key, value in run.config['sleep_mechanism'].items()})
    result.update(dict(run.summary))
    results.append(result)
results = pd.DataFrame(results).set_index('run')

# %%
results
# Out:
#                _runtime  _step    _timestamp              _wandb  \
# run
# Baseline-like      8285   2032  1.772069e+09   {'runtime': 8285}
# Baseline           9688   2014  1.771885e+09   {'runtime': 9688}
# Sleep             29669   2126  1.771834e+09  {'runtime': 29669}
#
#                eval/babylm_TEMPERATURE  eval/babylm_adjunct_island  \
# run
# Baseline-like                        1                        61.0
# Baseline                             1                        52.5
# Sleep                                1                        52.0
#
#                eval/babylm_anaphor_agreement  \
# run
# Baseline-like                          73.50
# Baseline                               73.00
# Sleep                                  53.25
#
#                eval/babylm_anaphor_gender_agreement  \
# run
# Baseline-like                                  66.5
# Baseline                                       68.0
# Sleep                                          54.5
#
#                eval/babylm_anaphor_number_agreement  \
# run
# Baseline-like                                  80.5
# Baseline                                       78.0
# Sleep                                          52.0
#
#                eval/babylm_animate_subject_passive  ...  \
# run                                                 ...
# Baseline-like                                 59.5  ...
# Baseline                                      59.5  ...
# Sleep                                         55.5  ...
#
#                eval/before_WAKE_babylm_wh_questions_subject_gap  \
# run
# Baseline-like                                               NaN
# Baseline                                                    NaN
# Sleep                                                      82.0
#
#                eval/before_WAKE_babylm_wh_questions_subject_gap_long_distance  \
# run
# Baseline-like                                                NaN
# Baseline                                                     NaN
# Sleep                                                       91.0
#
#                eval/before_WAKE_babylm_wh_vs_that_no_gap  \
# run
# Baseline-like                                        NaN
# Baseline                                             NaN
# Sleep                                               88.5
#
#                eval/before_WAKE_babylm_wh_vs_that_no_gap_long_distance  \
# run
# Baseline-like                                                NaN
# Baseline                                                     NaN
# Sleep                                                       85.5
#
#                eval/before_WAKE_babylm_wh_vs_that_with_gap  \
# run
# Baseline-like                                          NaN
# Baseline                                               NaN
# Sleep                                                 17.0
#
#                eval/before_WAKE_babylm_wh_vs_that_with_gap_long_distance  \
# run
# Baseline-like                                                NaN
# Baseline                                                     NaN
# Sleep                                                        8.0
#
#                eval/before_WAKE_perplexity_max  \
# run
# Baseline-like                              NaN
# Baseline                                   NaN
# Sleep                             10375.761719
#
#                eval/before_WAKE_perplexity_mean  \
# run
# Baseline-like                               NaN
# Baseline                                    NaN
# Sleep                               1437.671143
#
#                eval/before_WAKE_perplexity_std  eval/before_WAKE_runtime
# run
# Baseline-like                              NaN                       NaN
# Baseline                                   NaN                       NaN
# Sleep                              1657.641357                  229.4943
#
# [3 rows x 430 columns]

# %%
babylm_metrics = [col for col in results.columns if 'eval/babylm' in col]

# %% [markdown]
# ### Read in BabyLM Eval Results

# %%
result_path = "babylm_eval/sleep-baseline-like-run-eval/mlm"
result_path = Path(result_path)
result_path.exists()
# Out:
# False

# %%
def get_babylm_results(result_path, run_name=""):
    result_path_extended = Path(result_path) / "mlm"
    results = dict()
    for task in result_path_extended.iterdir():
        curr_task = dict()
        for subtask in task.iterdir():
            # curr_subtask = dict()
            results_filepath = subtask / "best_temperature_report.txt"
            if not results_filepath.exists():
                # print(f"Skip {results_filepath}")
                continue
            with open(results_filepath, 'r') as f:
                prefix=""
                for line in f.readlines():
                    if "###" in line:
                        prefix = line.strip("### ").strip()
                    elif ":" in line:
                        metric, value = line.split(":")
                        curr_task[f"{subtask.stem}_{prefix}_{metric}"] = float(value)
                    else:
                        try:
                            curr_task[f"{subtask.stem}_{prefix}"] = float(line)
                        except:
                            continue
            # curr_task[subtask.stem] = curr_subtask
        results[task.stem] = curr_task
    avg_results = dict()
    for task, accuracies in results.items():
        if len(accuracies) == 0:
            continue
        avg_accuracy = np.mean([accuracy for subtask, accuracy in accuracies.items() 
                             if ("TEMPERATURE" not in subtask) and ("AVERAGE" not in subtask)])
        avg_results[task] = avg_accuracy
    avg_results['overall'] = np.mean(list(avg_results.values()))
    avg_results['run'] = run_name or Path(result_path).stem
    return results, avg_results

# %%
baseline_like_res, baseline_like_avg = get_babylm_results("babylm_eval/sleep-baseline-like-run",
                                                          run_name="Baseline-like")
baseline_res, baseline_avg = get_babylm_results("babylm_eval/baseline-run",
                                                run_name="Baseline")
strict_red, strict_avg = get_babylm_results("babylm_eval/strict-replay-run",
                                            run_name="Sleep")

# %%
eval_results = pd.DataFrame([baseline_like_avg, 
                             baseline_avg,
                             strict_avg]).set_index('run')
eval_results['Test Perplexity'] = results['eval/best_perplexity_mean']
eval_results = eval_results.reset_index()
eval_results[['wug_adj', 'wug_past']] *= 100
eval_results = (eval_results
                .melt(id_vars='run',
                      var_name='task',
                      value_name='score'))
eval_results
# Out:
#               run             task       score
# 0   Baseline-like            blimp   59.469780
# 1        Baseline            blimp   59.367582
# 2           Sleep            blimp   53.393626
# 3   Baseline-like          wug_adj   52.000000
# 4        Baseline          wug_adj   53.000000
# 5           Sleep          wug_adj   67.000000
# 6   Baseline-like         wug_past   20.000000
# 7        Baseline         wug_past    1.000000
# 8           Sleep         wug_past  -10.000000
# 9   Baseline-like  entity_tracking   34.350000
# 10       Baseline  entity_tracking   33.735714
# 11          Sleep  entity_tracking   34.701429
# 12  Baseline-like          overall   23.634945
# 13       Baseline          overall   23.410824
# 14          Sleep          overall   22.166264
# 15  Baseline-like  Test Perplexity   38.631039
# 16       Baseline  Test Perplexity         NaN
# 17          Sleep  Test Perplexity  150.211060

# %%
eval_results.sort_values('run')
# Out:
#               run             task       score
# 1        Baseline            blimp   59.367582
# 4        Baseline          wug_adj   53.000000
# 7        Baseline         wug_past    1.000000
# 16       Baseline  Test Perplexity         NaN
# 10       Baseline  entity_tracking   33.735714
# 13       Baseline          overall   23.410824
# 0   Baseline-like            blimp   59.469780
# 15  Baseline-like  Test Perplexity   38.631039
# 3   Baseline-like          wug_adj   52.000000
# 6   Baseline-like         wug_past   20.000000
# 9   Baseline-like  entity_tracking   34.350000
# 12  Baseline-like          overall   23.634945
# 14          Sleep          overall   22.166264
# 8           Sleep         wug_past  -10.000000
# 5           Sleep          wug_adj   67.000000
# 2           Sleep            blimp   53.393626
# 11          Sleep  entity_tracking   34.701429
# 17          Sleep  Test Perplexity  150.211060

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5),
                       width_ratios=[5, 1])
sns.barplot(eval_results[eval_results['task'] != 'Test Perplexity'].sort_values('run'), 
            x='task', y='score', hue='run', 
            palette=model_cmap, ax=axs[0])
axs[0].legend(title="Model")
axs[0].set_title("BabyLM Eval Metrics")
axs[0].set_ylabel("Score")
axs[0].set_xlabel("")
axs[0].set_xticks(ticks=babylm_tasks, labels=babylm_tasks_formatted)
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

sns.barplot(eval_results[eval_results['task'] == 'Test Perplexity'].sort_values('run'), 
            x='task', y='score', hue='run', 
            palette=model_cmap, ax=axs[1])
axs[1].set_title("PPL")
axs[1].get_legend().remove()
axs[1].set_ylabel("Mean Test Perplexity")
axs[1].set_xlabel("")
axs[1].grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig("plots/babylm_eval.png", 
            bbox_inches='tight', dpi=300,
            transparent=True)
